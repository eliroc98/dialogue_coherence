# %%
import numpy as np
import json
import tensorflow as tf

from transformers import AutoTokenizer, AutoModel, utils
from bertviz import model_view, head_view

# %%
tokenizer = AutoTokenizer.from_pretrained("DeepPavlov/bert-base-cased-conversational")
model = AutoModel.from_pretrained("DeepPavlov/bert-base-cased-conversational", output_attentions=True)

with open('/Users/lizzy/Desktop/Universita/tesi/git/dialogue_coherence/clark/preprocessed_conversational.json', 'r') as f:
       texts = json.load(f)
       input_text = texts[0]["words"]
       input_text = " ".join(input_text)
       
inputs = tokenizer.encode(input_text, return_tensors='pt', add_special_tokens = False)  # Tokenize input text
outputs = model(inputs)  # Run model
attention = outputs[-1]  # Retrieve attention from model outputs
tokens = tokenizer.convert_ids_to_tokens(inputs[0])  # Convert input ids to token strings
# Out:
# Some weights of the model checkpoint at DeepPavlov/bert-base-cased-conversational were not used when initializing BertModel: ['cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
inputs[0]
# Out:
# tensor([  101,   750,  3119,   699, 25385,   119,   102,   146,   112,  1035,
#          4932,   795,   646, 14946,   119,   102])

# %%
for item in tokenizer.convert_ids_to_tokens(inputs[0]):
    print(item=="[CLS]")
# Out:
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
def get_token_positions(encoded_input, token, tokenizer):
    sep_pos = []
    i = 0
    for item in encoded_input:
        if item == token:
            sep_pos.append(i)
        i+=1
    return sep_pos

# %%
def from_torch_tensor2_numpy(tensor):
    arr = np.empty((len(tensor), tensor[0].size()[1], tensor[0].size()[-1], tensor[0].size()[-1]))
    for i, item in enumerate(tensor):
        arr[i] = item[0].cpu().detach().numpy()
    return arr

# %%
attentions = from_torch_tensor2_numpy(attention)

# %%
def perc_attention(tokens_to_pay_attention_to, attention, encoded_tokens, tokenizer):
    res = {}
    for tkn in tokens_to_pay_attention_to:
        perc_attention_to = np.zeros(shape = (np.shape(attention)[:-2]))
        perc_attention_from = np.zeros(shape = (np.shape(attention)[:-2]))
        for l, layer in enumerate(attention):
            for h, head in enumerate(layer):
                if tkn in ['current', 'next', 'previous']:
                    offset = switch_attention2(tkn)
                    sum_weights_to = np.trace(head, offset = offset)
                    sum_weights_from = np.trace(np.transpose(head), offset = offset)
                else:
                    tkn_pos = get_token_positions(encoded_tokens, tkn, tokenizer)
                    sum_weights_to = sum([itemj for i, itemi in enumerate(head) for j, itemj in enumerate(head[i]) if i in tkn_pos])
                    sum_weights_from = sum([itemj for i, itemi in enumerate(np.transpose(head)) for j, itemj in enumerate(np.transpose(head)[i]) if i in tkn_pos])
                    
                sum_tot = np.sum(head)
                perc_attention_to[l][h] = sum_weights_to/sum_tot
                perc_attention_from[l][h] = sum_weights_from/sum_tot
        res[tkn] = {'to': perc_attention_to, 'from':perc_attention_from}
    return res

# %%
get_token_positions(tokens, '[SEP]', tokenizer)
# Out:
# [6, 15]

# %%
tokens[0]
# Out:
# '[CLS]'

# %%
def switch_attention2(token_to_pay_attention_to):
    if token_to_pay_attention_to == 'current':
        return 0
    elif token_to_pay_attention_to == 'next':
        return 1
    elif token_to_pay_attention_to == 'previous':
        return -1
    else:
        raise Exception('Token not valid')

# %%
res = perc_attention(['current', 
                    'next', 
                    'previous', 
                    '[CLS]', 
                    '[SEP]'], 
                    attentions,
                    tokens,
                    tokenizer)

# %%
for key in res:
    for direction in res[key]:
        print(f"Attention {direction} {key} token")
        for l, layer in enumerate(res[key][direction]):
            for h, head in enumerate(res[key][direction][l]):
                print(f"Layer {l} head {h}: {np.around(res[key][direction][l][h], decimals = 2)}")
# Out:
# Attention to current token
# Layer 0 head 0: 0.12
# Layer 0 head 1: 0.08
# Layer 0 head 2: 0.08
# Layer 0 head 3: 0.07
# Layer 0 head 4: 0.11
# Layer 0 head 5: 0.08
# Layer 0 head 6: 0.08
# Layer 0 head 7: 0.04
# Layer 0 head 8: 0.09
# Layer 0 head 9: 0.07
# Layer 0 head 10: 0.34
# Layer 0 head 11: 0.08
# Layer 1 head 0: 0.08
# Layer 1 head 1: 0.07
# Layer 1 head 2: 0.06
# Layer 1 head 3: 0.04
# Layer 1 head 4: 0.05
# Layer 1 head 5: 0.09
# Layer 1 head 6: 0.1
# Layer 1 head 7: 0.07
# Layer 1 head 8: 0.03
# Layer 1 head 9: 0.03
# Layer 1 head 10: 0.05
# Layer 1 head 11: 0.06
# Layer 2 head 0: 0.06
# Layer 2 head 1: 0.04
# Layer 2 head 2: 0.17
# Layer 2 head 3: 0.05
# Layer 2 head 4: 0.07
# Layer 2 head 5: 0.12
# Layer 2 head 6: 0.05
# Layer 2 head 7: 0.08
# Layer 2 head 8: 0.06
# Layer 2 head 9: 0.09
# Layer 2 head 10: 0.08
# Layer 2 head 11: 0.11
# Layer 3 head 0: 0.08
# Layer 3 head 1: 0.13
# Layer 3 head 2: 0.08
# Layer 3 head 3: 0.08
# Layer 3 head 4: 0.07
# Layer 3 head 5: 0.1
# Layer 3 head 6: 0.12
# Layer 3 head 7: 0.24
# Layer 3 head 8: 0.05
# Layer 3 head 9: 0.08
# Layer 3 head 10: 0.08
# Layer 3 head 11: 0.03
# Layer 4 head 0: 0.09
# Layer 4 head 1: 0.07
# Layer 4 head 2: 0.07
# Layer 4 head 3: 0.08
# Layer 4 head 4: 0.11
# Layer 4 head 5: 0.07
# Layer 4 head 6: 0.08
# Layer 4 head 7: 0.08
# Layer 4 head 8: 0.08
# Layer 4 head 9: 0.07
# Layer 4 head 10: 0.08
# Layer 4 head 11: 0.08
# Layer 5 head 0: 0.08
# Layer 5 head 1: 0.06
# Layer 5 head 2: 0.07
# Layer 5 head 3: 0.09
# Layer 5 head 4: 0.08
# Layer 5 head 5: 0.09
# Layer 5 head 6: 0.07
# Layer 5 head 7: 0.1
# Layer 5 head 8: 0.08
# Layer 5 head 9: 0.07
# Layer 5 head 10: 0.07
# Layer 5 head 11: 0.08
# Layer 6 head 0: 0.1
# Layer 6 head 1: 0.07
# Layer 6 head 2: 0.07
# Layer 6 head 3: 0.09
# Layer 6 head 4: 0.08
# Layer 6 head 5: 0.08
# Layer 6 head 6: 0.09
# Layer 6 head 7: 0.09
# Layer 6 head 8: 0.08
# Layer 6 head 9: 0.06
# Layer 6 head 10: 0.07
# Layer 6 head 11: 0.11
# Layer 7 head 0: 0.07
# Layer 7 head 1: 0.09
# Layer 7 head 2: 0.07
# Layer 7 head 3: 0.09
# Layer 7 head 4: 0.08
# Layer 7 head 5: 0.1
# Layer 7 head 6: 0.09
# Layer 7 head 7: 0.09
# Layer 7 head 8: 0.09
# Layer 7 head 9: 0.07
# Layer 7 head 10: 0.09
# Layer 7 head 11: 0.07
# Layer 8 head 0: 0.08
# Layer 8 head 1: 0.09
# Layer 8 head 2: 0.07
# Layer 8 head 3: 0.09
# Layer 8 head 4: 0.07
# Layer 8 head 5: 0.07
# Layer 8 head 6: 0.08
# Layer 8 head 7: 0.09
# Layer 8 head 8: 0.08
# Layer 8 head 9: 0.07
# Layer 8 head 10: 0.13
# Layer 8 head 11: 0.14
# Layer 9 head 0: 0.08
# Layer 9 head 1: 0.19
# Layer 9 head 2: 0.08
# Layer 9 head 3: 0.1
# Layer 9 head 4: 0.07
# Layer 9 head 5: 0.08
# Layer 9 head 6: 0.08
# Layer 9 head 7: 0.07
# Layer 9 head 8: 0.09
# Layer 9 head 9: 0.11
# Layer 9 head 10: 0.1
# Layer 9 head 11: 0.07
# Layer 10 head 0: 0.07
# Layer 10 head 1: 0.11
# Layer 10 head 2: 0.12
# Layer 10 head 3: 0.09
# Layer 10 head 4: 0.08
# Layer 10 head 5: 0.09
# Layer 10 head 6: 0.07
# Layer 10 head 7: 0.08
# Layer 10 head 8: 0.1
# Layer 10 head 9: 0.08
# Layer 10 head 10: 0.03
# Layer 10 head 11: 0.08
# Layer 11 head 0: 0.02
# Layer 11 head 1: 0.02
# Layer 11 head 2: 0.42
# Layer 11 head 3: 0.56
# Layer 11 head 4: 0.03
# Layer 11 head 5: 0.03
# Layer 11 head 6: 0.02
# Layer 11 head 7: 0.02
# Layer 11 head 8: 0.03
# Layer 11 head 9: 0.04
# Layer 11 head 10: 0.03
# Layer 11 head 11: 0.48
# Attention from current token
# Layer 0 head 0: 0.12
# Layer 0 head 1: 0.08
# Layer 0 head 2: 0.08
# Layer 0 head 3: 0.07
# Layer 0 head 4: 0.11
# Layer 0 head 5: 0.08
# Layer 0 head 6: 0.08
# Layer 0 head 7: 0.04
# Layer 0 head 8: 0.09
# Layer 0 head 9: 0.07
# Layer 0 head 10: 0.34
# Layer 0 head 11: 0.08
# Layer 1 head 0: 0.08
# Layer 1 head 1: 0.07
# Layer 1 head 2: 0.06
# Layer 1 head 3: 0.04
# Layer 1 head 4: 0.05
# Layer 1 head 5: 0.09
# Layer 1 head 6: 0.1
# Layer 1 head 7: 0.07
# Layer 1 head 8: 0.03
# Layer 1 head 9: 0.03
# Layer 1 head 10: 0.05
# Layer 1 head 11: 0.06
# Layer 2 head 0: 0.06
# Layer 2 head 1: 0.04
# Layer 2 head 2: 0.17
# Layer 2 head 3: 0.05
# Layer 2 head 4: 0.07
# Layer 2 head 5: 0.12
# Layer 2 head 6: 0.05
# Layer 2 head 7: 0.08
# Layer 2 head 8: 0.06
# Layer 2 head 9: 0.09
# Layer 2 head 10: 0.08
# Layer 2 head 11: 0.11
# Layer 3 head 0: 0.08
# Layer 3 head 1: 0.13
# Layer 3 head 2: 0.08
# Layer 3 head 3: 0.08
# Layer 3 head 4: 0.07
# Layer 3 head 5: 0.1
# Layer 3 head 6: 0.12
# Layer 3 head 7: 0.24
# Layer 3 head 8: 0.05
# Layer 3 head 9: 0.08
# Layer 3 head 10: 0.08
# Layer 3 head 11: 0.03
# Layer 4 head 0: 0.09
# Layer 4 head 1: 0.07
# Layer 4 head 2: 0.07
# Layer 4 head 3: 0.08
# Layer 4 head 4: 0.11
# Layer 4 head 5: 0.07
# Layer 4 head 6: 0.08
# Layer 4 head 7: 0.08
# Layer 4 head 8: 0.08
# Layer 4 head 9: 0.07
# Layer 4 head 10: 0.08
# Layer 4 head 11: 0.08
# Layer 5 head 0: 0.08
# Layer 5 head 1: 0.06
# Layer 5 head 2: 0.07
# Layer 5 head 3: 0.09
# Layer 5 head 4: 0.08
# Layer 5 head 5: 0.09
# Layer 5 head 6: 0.07
# Layer 5 head 7: 0.1
# Layer 5 head 8: 0.08
# Layer 5 head 9: 0.07
# Layer 5 head 10: 0.07
# Layer 5 head 11: 0.08
# Layer 6 head 0: 0.1
# Layer 6 head 1: 0.07
# Layer 6 head 2: 0.07
# Layer 6 head 3: 0.09
# Layer 6 head 4: 0.08
# Layer 6 head 5: 0.08
# Layer 6 head 6: 0.09
# Layer 6 head 7: 0.09
# Layer 6 head 8: 0.08
# Layer 6 head 9: 0.06
# Layer 6 head 10: 0.07
# Layer 6 head 11: 0.11
# Layer 7 head 0: 0.07
# Layer 7 head 1: 0.09
# Layer 7 head 2: 0.07
# Layer 7 head 3: 0.09
# Layer 7 head 4: 0.08
# Layer 7 head 5: 0.1
# Layer 7 head 6: 0.09
# Layer 7 head 7: 0.09
# Layer 7 head 8: 0.09
# Layer 7 head 9: 0.07
# Layer 7 head 10: 0.09
# Layer 7 head 11: 0.07
# Layer 8 head 0: 0.08
# Layer 8 head 1: 0.09
# Layer 8 head 2: 0.07
# Layer 8 head 3: 0.09
# Layer 8 head 4: 0.07
# Layer 8 head 5: 0.07
# Layer 8 head 6: 0.08
# Layer 8 head 7: 0.09
# Layer 8 head 8: 0.08
# Layer 8 head 9: 0.07
# Layer 8 head 10: 0.13
# Layer 8 head 11: 0.14
# Layer 9 head 0: 0.08
# Layer 9 head 1: 0.19
# Layer 9 head 2: 0.08
# Layer 9 head 3: 0.1
# Layer 9 head 4: 0.07
# Layer 9 head 5: 0.08
# Layer 9 head 6: 0.08
# Layer 9 head 7: 0.07
# Layer 9 head 8: 0.09
# Layer 9 head 9: 0.11
# Layer 9 head 10: 0.1
# Layer 9 head 11: 0.07
# Layer 10 head 0: 0.07
# Layer 10 head 1: 0.11
# Layer 10 head 2: 0.12
# Layer 10 head 3: 0.09
# Layer 10 head 4: 0.08
# Layer 10 head 5: 0.09
# Layer 10 head 6: 0.07
# Layer 10 head 7: 0.08
# Layer 10 head 8: 0.1
# Layer 10 head 9: 0.08
# Layer 10 head 10: 0.03
# Layer 10 head 11: 0.08
# Layer 11 head 0: 0.02
# Layer 11 head 1: 0.02
# Layer 11 head 2: 0.42
# Layer 11 head 3: 0.56
# Layer 11 head 4: 0.03
# Layer 11 head 5: 0.03
# Layer 11 head 6: 0.02
# Layer 11 head 7: 0.02
# Layer 11 head 8: 0.03
# Layer 11 head 9: 0.04
# Layer 11 head 10: 0.03
# Layer 11 head 11: 0.48
# Attention to next token
# Layer 0 head 0: 0.05
# Layer 0 head 1: 0.02
# Layer 0 head 2: 0.07
# Layer 0 head 3: 0.72
# Layer 0 head 4: 0.06
# Layer 0 head 5: 0.14
# Layer 0 head 6: 0.15
# Layer 0 head 7: 0.05
# Layer 0 head 8: 0.07
# Layer 0 head 9: 0.06
# Layer 0 head 10: 0.03
# Layer 0 head 11: 0.02
# Layer 1 head 0: 0.03
# Layer 1 head 1: 0.08
# Layer 1 head 2: 0.01
# Layer 1 head 3: 0.38
# Layer 1 head 4: 0.0
# Layer 1 head 5: 0.06
# Layer 1 head 6: 0.03
# Layer 1 head 7: 0.02
# Layer 1 head 8: 0.04
# Layer 1 head 9: 0.03
# Layer 1 head 10: 0.01
# Layer 1 head 11: 0.64
# Layer 2 head 0: 0.06
# Layer 2 head 1: 0.02
# Layer 2 head 2: 0.04
# Layer 2 head 3: 0.72
# Layer 2 head 4: 0.19
# Layer 2 head 5: 0.03
# Layer 2 head 6: 0.05
# Layer 2 head 7: 0.07
# Layer 2 head 8: 0.04
# Layer 2 head 9: 0.08
# Layer 2 head 10: 0.1
# Layer 2 head 11: 0.06
# Layer 3 head 0: 0.07
# Layer 3 head 1: 0.04
# Layer 3 head 2: 0.04
# Layer 3 head 3: 0.05
# Layer 3 head 4: 0.17
# Layer 3 head 5: 0.09
# Layer 3 head 6: 0.06
# Layer 3 head 7: 0.06
# Layer 3 head 8: 0.04
# Layer 3 head 9: 0.15
# Layer 3 head 10: 0.05
# Layer 3 head 11: 0.01
# Layer 4 head 0: 0.05
# Layer 4 head 1: 0.05
# Layer 4 head 2: 0.03
# Layer 4 head 3: 0.13
# Layer 4 head 4: 0.08
# Layer 4 head 5: 0.22
# Layer 4 head 6: 0.03
# Layer 4 head 7: 0.06
# Layer 4 head 8: 0.08
# Layer 4 head 9: 0.14
# Layer 4 head 10: 0.06
# Layer 4 head 11: 0.04
# Layer 5 head 0: 0.03
# Layer 5 head 1: 0.04
# Layer 5 head 2: 0.05
# Layer 5 head 3: 0.02
# Layer 5 head 4: 0.2
# Layer 5 head 5: 0.05
# Layer 5 head 6: 0.19
# Layer 5 head 7: 0.06
# Layer 5 head 8: 0.17
# Layer 5 head 9: 0.13
# Layer 5 head 10: 0.06
# Layer 5 head 11: 0.05
# Layer 6 head 0: 0.05
# Layer 6 head 1: 0.05
# Layer 6 head 2: 0.06
# Layer 6 head 3: 0.1
# Layer 6 head 4: 0.15
# Layer 6 head 5: 0.02
# Layer 6 head 6: 0.04
# Layer 6 head 7: 0.1
# Layer 6 head 8: 0.1
# Layer 6 head 9: 0.5
# Layer 6 head 10: 0.09
# Layer 6 head 11: 0.07
# Layer 7 head 0: 0.05
# Layer 7 head 1: 0.04
# Layer 7 head 2: 0.08
# Layer 7 head 3: 0.09
# Layer 7 head 4: 0.13
# Layer 7 head 5: 0.03
# Layer 7 head 6: 0.04
# Layer 7 head 7: 0.05
# Layer 7 head 8: 0.09
# Layer 7 head 9: 0.06
# Layer 7 head 10: 0.04
# Layer 7 head 11: 0.06
# Layer 8 head 0: 0.06
# Layer 8 head 1: 0.07
# Layer 8 head 2: 0.04
# Layer 8 head 3: 0.05
# Layer 8 head 4: 0.05
# Layer 8 head 5: 0.06
# Layer 8 head 6: 0.03
# Layer 8 head 7: 0.04
# Layer 8 head 8: 0.05
# Layer 8 head 9: 0.13
# Layer 8 head 10: 0.06
# Layer 8 head 11: 0.07
# Layer 9 head 0: 0.08
# Layer 9 head 1: 0.09
# Layer 9 head 2: 0.07
# Layer 9 head 3: 0.03
# Layer 9 head 4: 0.06
# Layer 9 head 5: 0.05
# Layer 9 head 6: 0.04
# Layer 9 head 7: 0.08
# Layer 9 head 8: 0.04
# Layer 9 head 9: 0.06
# Layer 9 head 10: 0.04
# Layer 9 head 11: 0.15
# Layer 10 head 0: 0.07
# Layer 10 head 1: 0.05
# Layer 10 head 2: 0.08
# Layer 10 head 3: 0.06
# Layer 10 head 4: 0.08
# Layer 10 head 5: 0.05
# Layer 10 head 6: 0.05
# Layer 10 head 7: 0.09
# Layer 10 head 8: 0.06
# Layer 10 head 9: 0.07
# Layer 10 head 10: 0.07
# Layer 10 head 11: 0.06
# Layer 11 head 0: 0.07
# Layer 11 head 1: 0.07
# Layer 11 head 2: 0.04
# Layer 11 head 3: 0.02
# Layer 11 head 4: 0.06
# Layer 11 head 5: 0.07
# Layer 11 head 6: 0.11
# Layer 11 head 7: 0.07
# Layer 11 head 8: 0.04
# Layer 11 head 9: 0.06
# Layer 11 head 10: 0.07
# Layer 11 head 11: 0.02
# Attention from next token
# Layer 0 head 0: 0.05
# Layer 0 head 1: 0.6
# Layer 0 head 2: 0.05
# Layer 0 head 3: 0.02
# Layer 0 head 4: 0.07
# Layer 0 head 5: 0.11
# Layer 0 head 6: 0.21
# Layer 0 head 7: 0.1
# Layer 0 head 8: 0.06
# Layer 0 head 9: 0.06
# Layer 0 head 10: 0.04
# Layer 0 head 11: 0.07
# Layer 1 head 0: 0.04
# Layer 1 head 1: 0.01
# Layer 1 head 2: 0.19
# Layer 1 head 3: 0.02
# Layer 1 head 4: 0.48
# Layer 1 head 5: 0.1
# Layer 1 head 6: 0.06
# Layer 1 head 7: 0.12
# Layer 1 head 8: 0.07
# Layer 1 head 9: 0.02
# Layer 1 head 10: 0.07
# Layer 1 head 11: 0.01
# Layer 2 head 0: 0.04
# Layer 2 head 1: 0.3
# Layer 2 head 2: 0.04
# Layer 2 head 3: 0.0
# Layer 2 head 4: 0.01
# Layer 2 head 5: 0.04
# Layer 2 head 6: 0.04
# Layer 2 head 7: 0.03
# Layer 2 head 8: 0.06
# Layer 2 head 9: 0.05
# Layer 2 head 10: 0.05
# Layer 2 head 11: 0.08
# Layer 3 head 0: 0.04
# Layer 3 head 1: 0.03
# Layer 3 head 2: 0.03
# Layer 3 head 3: 0.05
# Layer 3 head 4: 0.01
# Layer 3 head 5: 0.06
# Layer 3 head 6: 0.03
# Layer 3 head 7: 0.03
# Layer 3 head 8: 0.04
# Layer 3 head 9: 0.16
# Layer 3 head 10: 0.09
# Layer 3 head 11: 0.63
# Layer 4 head 0: 0.03
# Layer 4 head 1: 0.04
# Layer 4 head 2: 0.11
# Layer 4 head 3: 0.1
# Layer 4 head 4: 0.03
# Layer 4 head 5: 0.02
# Layer 4 head 6: 0.03
# Layer 4 head 7: 0.04
# Layer 4 head 8: 0.03
# Layer 4 head 9: 0.06
# Layer 4 head 10: 0.04
# Layer 4 head 11: 0.04
# Layer 5 head 0: 0.03
# Layer 5 head 1: 0.34
# Layer 5 head 2: 0.11
# Layer 5 head 3: 0.03
# Layer 5 head 4: 0.04
# Layer 5 head 5: 0.04
# Layer 5 head 6: 0.06
# Layer 5 head 7: 0.11
# Layer 5 head 8: 0.02
# Layer 5 head 9: 0.07
# Layer 5 head 10: 0.09
# Layer 5 head 11: 0.02
# Layer 6 head 0: 0.04
# Layer 6 head 1: 0.18
# Layer 6 head 2: 0.07
# Layer 6 head 3: 0.08
# Layer 6 head 4: 0.02
# Layer 6 head 5: 0.07
# Layer 6 head 6: 0.03
# Layer 6 head 7: 0.02
# Layer 6 head 8: 0.02
# Layer 6 head 9: 0.01
# Layer 6 head 10: 0.03
# Layer 6 head 11: 0.04
# Layer 7 head 0: 0.15
# Layer 7 head 1: 0.1
# Layer 7 head 2: 0.05
# Layer 7 head 3: 0.02
# Layer 7 head 4: 0.02
# Layer 7 head 5: 0.03
# Layer 7 head 6: 0.07
# Layer 7 head 7: 0.04
# Layer 7 head 8: 0.06
# Layer 7 head 9: 0.04
# Layer 7 head 10: 0.07
# Layer 7 head 11: 0.08
# Layer 8 head 0: 0.1
# Layer 8 head 1: 0.04
# Layer 8 head 2: 0.03
# Layer 8 head 3: 0.04
# Layer 8 head 4: 0.05
# Layer 8 head 5: 0.04
# Layer 8 head 6: 0.05
# Layer 8 head 7: 0.03
# Layer 8 head 8: 0.04
# Layer 8 head 9: 0.02
# Layer 8 head 10: 0.05
# Layer 8 head 11: 0.04
# Layer 9 head 0: 0.03
# Layer 9 head 1: 0.03
# Layer 9 head 2: 0.04
# Layer 9 head 3: 0.05
# Layer 9 head 4: 0.04
# Layer 9 head 5: 0.06
# Layer 9 head 6: 0.05
# Layer 9 head 7: 0.09
# Layer 9 head 8: 0.04
# Layer 9 head 9: 0.05
# Layer 9 head 10: 0.03
# Layer 9 head 11: 0.03
# Layer 10 head 0: 0.03
# Layer 10 head 1: 0.05
# Layer 10 head 2: 0.04
# Layer 10 head 3: 0.03
# Layer 10 head 4: 0.04
# Layer 10 head 5: 0.03
# Layer 10 head 6: 0.22
# Layer 10 head 7: 0.04
# Layer 10 head 8: 0.02
# Layer 10 head 9: 0.07
# Layer 10 head 10: 0.04
# Layer 10 head 11: 0.03
# Layer 11 head 0: 0.04
# Layer 11 head 1: 0.04
# Layer 11 head 2: 0.03
# Layer 11 head 3: 0.02
# Layer 11 head 4: 0.04
# Layer 11 head 5: 0.04
# Layer 11 head 6: 0.05
# Layer 11 head 7: 0.04
# Layer 11 head 8: 0.05
# Layer 11 head 9: 0.05
# Layer 11 head 10: 0.05
# Layer 11 head 11: 0.02
# Attention to previous token
# Layer 0 head 0: 0.05
# Layer 0 head 1: 0.6
# Layer 0 head 2: 0.05
# Layer 0 head 3: 0.02
# Layer 0 head 4: 0.07
# Layer 0 head 5: 0.11
# Layer 0 head 6: 0.21
# Layer 0 head 7: 0.1
# Layer 0 head 8: 0.06
# Layer 0 head 9: 0.06
# Layer 0 head 10: 0.04
# Layer 0 head 11: 0.07
# Layer 1 head 0: 0.04
# Layer 1 head 1: 0.01
# Layer 1 head 2: 0.19
# Layer 1 head 3: 0.02
# Layer 1 head 4: 0.48
# Layer 1 head 5: 0.1
# Layer 1 head 6: 0.06
# Layer 1 head 7: 0.12
# Layer 1 head 8: 0.07
# Layer 1 head 9: 0.02
# Layer 1 head 10: 0.07
# Layer 1 head 11: 0.01
# Layer 2 head 0: 0.04
# Layer 2 head 1: 0.3
# Layer 2 head 2: 0.04
# Layer 2 head 3: 0.0
# Layer 2 head 4: 0.01
# Layer 2 head 5: 0.04
# Layer 2 head 6: 0.04
# Layer 2 head 7: 0.03
# Layer 2 head 8: 0.06
# Layer 2 head 9: 0.05
# Layer 2 head 10: 0.05
# Layer 2 head 11: 0.08
# Layer 3 head 0: 0.04
# Layer 3 head 1: 0.03
# Layer 3 head 2: 0.03
# Layer 3 head 3: 0.05
# Layer 3 head 4: 0.01
# Layer 3 head 5: 0.06
# Layer 3 head 6: 0.03
# Layer 3 head 7: 0.03
# Layer 3 head 8: 0.04
# Layer 3 head 9: 0.16
# Layer 3 head 10: 0.09
# Layer 3 head 11: 0.63
# Layer 4 head 0: 0.03
# Layer 4 head 1: 0.04
# Layer 4 head 2: 0.11
# Layer 4 head 3: 0.1
# Layer 4 head 4: 0.03
# Layer 4 head 5: 0.02
# Layer 4 head 6: 0.03
# Layer 4 head 7: 0.04
# Layer 4 head 8: 0.03
# Layer 4 head 9: 0.06
# Layer 4 head 10: 0.04
# Layer 4 head 11: 0.04
# Layer 5 head 0: 0.03
# Layer 5 head 1: 0.34
# Layer 5 head 2: 0.11
# Layer 5 head 3: 0.03
# Layer 5 head 4: 0.04
# Layer 5 head 5: 0.04
# Layer 5 head 6: 0.06
# Layer 5 head 7: 0.11
# Layer 5 head 8: 0.02
# Layer 5 head 9: 0.07
# Layer 5 head 10: 0.09
# Layer 5 head 11: 0.02
# Layer 6 head 0: 0.04
# Layer 6 head 1: 0.18
# Layer 6 head 2: 0.07
# Layer 6 head 3: 0.08
# Layer 6 head 4: 0.02
# Layer 6 head 5: 0.07
# Layer 6 head 6: 0.03
# Layer 6 head 7: 0.02
# Layer 6 head 8: 0.02
# Layer 6 head 9: 0.01
# Layer 6 head 10: 0.03
# Layer 6 head 11: 0.04
# Layer 7 head 0: 0.15
# Layer 7 head 1: 0.1
# Layer 7 head 2: 0.05
# Layer 7 head 3: 0.02
# Layer 7 head 4: 0.02
# Layer 7 head 5: 0.03
# Layer 7 head 6: 0.07
# Layer 7 head 7: 0.04
# Layer 7 head 8: 0.06
# Layer 7 head 9: 0.04
# Layer 7 head 10: 0.07
# Layer 7 head 11: 0.08
# Layer 8 head 0: 0.1
# Layer 8 head 1: 0.04
# Layer 8 head 2: 0.03
# Layer 8 head 3: 0.04
# Layer 8 head 4: 0.05
# Layer 8 head 5: 0.04
# Layer 8 head 6: 0.05
# Layer 8 head 7: 0.03
# Layer 8 head 8: 0.04
# Layer 8 head 9: 0.02
# Layer 8 head 10: 0.05
# Layer 8 head 11: 0.04
# Layer 9 head 0: 0.03
# Layer 9 head 1: 0.03
# Layer 9 head 2: 0.04
# Layer 9 head 3: 0.05
# Layer 9 head 4: 0.04
# Layer 9 head 5: 0.06
# Layer 9 head 6: 0.05
# Layer 9 head 7: 0.09
# Layer 9 head 8: 0.04
# Layer 9 head 9: 0.05
# Layer 9 head 10: 0.03
# Layer 9 head 11: 0.03
# Layer 10 head 0: 0.03
# Layer 10 head 1: 0.05
# Layer 10 head 2: 0.04
# Layer 10 head 3: 0.03
# Layer 10 head 4: 0.04
# Layer 10 head 5: 0.03
# Layer 10 head 6: 0.22
# Layer 10 head 7: 0.04
# Layer 10 head 8: 0.02
# Layer 10 head 9: 0.07
# Layer 10 head 10: 0.04
# Layer 10 head 11: 0.03
# Layer 11 head 0: 0.04
# Layer 11 head 1: 0.04
# Layer 11 head 2: 0.03
# Layer 11 head 3: 0.02
# Layer 11 head 4: 0.04
# Layer 11 head 5: 0.04
# Layer 11 head 6: 0.05
# Layer 11 head 7: 0.04
# Layer 11 head 8: 0.05
# Layer 11 head 9: 0.05
# Layer 11 head 10: 0.05
# Layer 11 head 11: 0.02
# Attention from previous token
# Layer 0 head 0: 0.05
# Layer 0 head 1: 0.02
# Layer 0 head 2: 0.07
# Layer 0 head 3: 0.72
# Layer 0 head 4: 0.06
# Layer 0 head 5: 0.14
# Layer 0 head 6: 0.15
# Layer 0 head 7: 0.05
# Layer 0 head 8: 0.07
# Layer 0 head 9: 0.06
# Layer 0 head 10: 0.03
# Layer 0 head 11: 0.02
# Layer 1 head 0: 0.03
# Layer 1 head 1: 0.08
# Layer 1 head 2: 0.01
# Layer 1 head 3: 0.38
# Layer 1 head 4: 0.0
# Layer 1 head 5: 0.06
# Layer 1 head 6: 0.03
# Layer 1 head 7: 0.02
# Layer 1 head 8: 0.04
# Layer 1 head 9: 0.03
# Layer 1 head 10: 0.01
# Layer 1 head 11: 0.64
# Layer 2 head 0: 0.06
# Layer 2 head 1: 0.02
# Layer 2 head 2: 0.04
# Layer 2 head 3: 0.72
# Layer 2 head 4: 0.19
# Layer 2 head 5: 0.03
# Layer 2 head 6: 0.05
# Layer 2 head 7: 0.07
# Layer 2 head 8: 0.04
# Layer 2 head 9: 0.08
# Layer 2 head 10: 0.1
# Layer 2 head 11: 0.06
# Layer 3 head 0: 0.07
# Layer 3 head 1: 0.04
# Layer 3 head 2: 0.04
# Layer 3 head 3: 0.05
# Layer 3 head 4: 0.17
# Layer 3 head 5: 0.09
# Layer 3 head 6: 0.06
# Layer 3 head 7: 0.06
# Layer 3 head 8: 0.04
# Layer 3 head 9: 0.15
# Layer 3 head 10: 0.05
# Layer 3 head 11: 0.01
# Layer 4 head 0: 0.05
# Layer 4 head 1: 0.05
# Layer 4 head 2: 0.03
# Layer 4 head 3: 0.13
# Layer 4 head 4: 0.08
# Layer 4 head 5: 0.22
# Layer 4 head 6: 0.03
# Layer 4 head 7: 0.06
# Layer 4 head 8: 0.08
# Layer 4 head 9: 0.14
# Layer 4 head 10: 0.06
# Layer 4 head 11: 0.04
# Layer 5 head 0: 0.03
# Layer 5 head 1: 0.04
# Layer 5 head 2: 0.05
# Layer 5 head 3: 0.02
# Layer 5 head 4: 0.2
# Layer 5 head 5: 0.05
# Layer 5 head 6: 0.19
# Layer 5 head 7: 0.06
# Layer 5 head 8: 0.17
# Layer 5 head 9: 0.13
# Layer 5 head 10: 0.06
# Layer 5 head 11: 0.05
# Layer 6 head 0: 0.05
# Layer 6 head 1: 0.05
# Layer 6 head 2: 0.06
# Layer 6 head 3: 0.1
# Layer 6 head 4: 0.15
# Layer 6 head 5: 0.02
# Layer 6 head 6: 0.04
# Layer 6 head 7: 0.1
# Layer 6 head 8: 0.1
# Layer 6 head 9: 0.5
# Layer 6 head 10: 0.09
# Layer 6 head 11: 0.07
# Layer 7 head 0: 0.05
# Layer 7 head 1: 0.04
# Layer 7 head 2: 0.08
# Layer 7 head 3: 0.09
# Layer 7 head 4: 0.13
# Layer 7 head 5: 0.03
# Layer 7 head 6: 0.04
# Layer 7 head 7: 0.05
# Layer 7 head 8: 0.09
# Layer 7 head 9: 0.06
# Layer 7 head 10: 0.04
# Layer 7 head 11: 0.06
# Layer 8 head 0: 0.06
# Layer 8 head 1: 0.07
# Layer 8 head 2: 0.04
# Layer 8 head 3: 0.05
# Layer 8 head 4: 0.05
# Layer 8 head 5: 0.06
# Layer 8 head 6: 0.03
# Layer 8 head 7: 0.04
# Layer 8 head 8: 0.05
# Layer 8 head 9: 0.13
# Layer 8 head 10: 0.06
# Layer 8 head 11: 0.07
# Layer 9 head 0: 0.08
# Layer 9 head 1: 0.09
# Layer 9 head 2: 0.07
# Layer 9 head 3: 0.03
# Layer 9 head 4: 0.06
# Layer 9 head 5: 0.05
# Layer 9 head 6: 0.04
# Layer 9 head 7: 0.08
# Layer 9 head 8: 0.04
# Layer 9 head 9: 0.06
# Layer 9 head 10: 0.04
# Layer 9 head 11: 0.15
# Layer 10 head 0: 0.07
# Layer 10 head 1: 0.05
# Layer 10 head 2: 0.08
# Layer 10 head 3: 0.06
# Layer 10 head 4: 0.08
# Layer 10 head 5: 0.05
# Layer 10 head 6: 0.05
# Layer 10 head 7: 0.09
# Layer 10 head 8: 0.06
# Layer 10 head 9: 0.07
# Layer 10 head 10: 0.07
# Layer 10 head 11: 0.06
# Layer 11 head 0: 0.07
# Layer 11 head 1: 0.07
# Layer 11 head 2: 0.04
# Layer 11 head 3: 0.02
# Layer 11 head 4: 0.06
# Layer 11 head 5: 0.07
# Layer 11 head 6: 0.11
# Layer 11 head 7: 0.07
# Layer 11 head 8: 0.04
# Layer 11 head 9: 0.06
# Layer 11 head 10: 0.07
# Layer 11 head 11: 0.02
# Attention to [CLS] token
# Layer 0 head 0: 0.06
# Layer 0 head 1: 0.06
# Layer 0 head 2: 0.06
# Layer 0 head 3: 0.06
# Layer 0 head 4: 0.06
# Layer 0 head 5: 0.06
# Layer 0 head 6: 0.06
# Layer 0 head 7: 0.06
# Layer 0 head 8: 0.06
# Layer 0 head 9: 0.06
# Layer 0 head 10: 0.06
# Layer 0 head 11: 0.06
# Layer 1 head 0: 0.06
# Layer 1 head 1: 0.06
# Layer 1 head 2: 0.06
# Layer 1 head 3: 0.06
# Layer 1 head 4: 0.06
# Layer 1 head 5: 0.06
# Layer 1 head 6: 0.06
# Layer 1 head 7: 0.06
# Layer 1 head 8: 0.06
# Layer 1 head 9: 0.06
# Layer 1 head 10: 0.06
# Layer 1 head 11: 0.06
# Layer 2 head 0: 0.06
# Layer 2 head 1: 0.06
# Layer 2 head 2: 0.06
# Layer 2 head 3: 0.06
# Layer 2 head 4: 0.06
# Layer 2 head 5: 0.06
# Layer 2 head 6: 0.06
# Layer 2 head 7: 0.06
# Layer 2 head 8: 0.06
# Layer 2 head 9: 0.06
# Layer 2 head 10: 0.06
# Layer 2 head 11: 0.06
# Layer 3 head 0: 0.06
# Layer 3 head 1: 0.06
# Layer 3 head 2: 0.06
# Layer 3 head 3: 0.06
# Layer 3 head 4: 0.06
# Layer 3 head 5: 0.06
# Layer 3 head 6: 0.06
# Layer 3 head 7: 0.06
# Layer 3 head 8: 0.06
# Layer 3 head 9: 0.06
# Layer 3 head 10: 0.06
# Layer 3 head 11: 0.06
# Layer 4 head 0: 0.06
# Layer 4 head 1: 0.06
# Layer 4 head 2: 0.06
# Layer 4 head 3: 0.06
# Layer 4 head 4: 0.06
# Layer 4 head 5: 0.06
# Layer 4 head 6: 0.06
# Layer 4 head 7: 0.06
# Layer 4 head 8: 0.06
# Layer 4 head 9: 0.06
# Layer 4 head 10: 0.06
# Layer 4 head 11: 0.06
# Layer 5 head 0: 0.06
# Layer 5 head 1: 0.06
# Layer 5 head 2: 0.06
# Layer 5 head 3: 0.06
# Layer 5 head 4: 0.06
# Layer 5 head 5: 0.06
# Layer 5 head 6: 0.06
# Layer 5 head 7: 0.06
# Layer 5 head 8: 0.06
# Layer 5 head 9: 0.06
# Layer 5 head 10: 0.06
# Layer 5 head 11: 0.06
# Layer 6 head 0: 0.06
# Layer 6 head 1: 0.06
# Layer 6 head 2: 0.06
# Layer 6 head 3: 0.06
# Layer 6 head 4: 0.06
# Layer 6 head 5: 0.06
# Layer 6 head 6: 0.06
# Layer 6 head 7: 0.06
# Layer 6 head 8: 0.06
# Layer 6 head 9: 0.06
# Layer 6 head 10: 0.06
# Layer 6 head 11: 0.06
# Layer 7 head 0: 0.06
# Layer 7 head 1: 0.06
# Layer 7 head 2: 0.06
# Layer 7 head 3: 0.06
# Layer 7 head 4: 0.06
# Layer 7 head 5: 0.06
# Layer 7 head 6: 0.06
# Layer 7 head 7: 0.06
# Layer 7 head 8: 0.06
# Layer 7 head 9: 0.06
# Layer 7 head 10: 0.06
# Layer 7 head 11: 0.06
# Layer 8 head 0: 0.06
# Layer 8 head 1: 0.06
# Layer 8 head 2: 0.06
# Layer 8 head 3: 0.06
# Layer 8 head 4: 0.06
# Layer 8 head 5: 0.06
# Layer 8 head 6: 0.06
# Layer 8 head 7: 0.06
# Layer 8 head 8: 0.06
# Layer 8 head 9: 0.06
# Layer 8 head 10: 0.06
# Layer 8 head 11: 0.06
# Layer 9 head 0: 0.06
# Layer 9 head 1: 0.06
# Layer 9 head 2: 0.06
# Layer 9 head 3: 0.06
# Layer 9 head 4: 0.06
# Layer 9 head 5: 0.06
# Layer 9 head 6: 0.06
# Layer 9 head 7: 0.06
# Layer 9 head 8: 0.06
# Layer 9 head 9: 0.06
# Layer 9 head 10: 0.06
# Layer 9 head 11: 0.06
# Layer 10 head 0: 0.06
# Layer 10 head 1: 0.06
# Layer 10 head 2: 0.06
# Layer 10 head 3: 0.06
# Layer 10 head 4: 0.06
# Layer 10 head 5: 0.06
# Layer 10 head 6: 0.06
# Layer 10 head 7: 0.06
# Layer 10 head 8: 0.06
# Layer 10 head 9: 0.06
# Layer 10 head 10: 0.06
# Layer 10 head 11: 0.06
# Layer 11 head 0: 0.06
# Layer 11 head 1: 0.06
# Layer 11 head 2: 0.06
# Layer 11 head 3: 0.06
# Layer 11 head 4: 0.06
# Layer 11 head 5: 0.06
# Layer 11 head 6: 0.06
# Layer 11 head 7: 0.06
# Layer 11 head 8: 0.06
# Layer 11 head 9: 0.06
# Layer 11 head 10: 0.06
# Layer 11 head 11: 0.06
# Attention from [CLS] token
# Layer 0 head 0: 0.13
# Layer 0 head 1: 0.11
# Layer 0 head 2: 0.09
# Layer 0 head 3: 0.18
# Layer 0 head 4: 0.11
# Layer 0 head 5: 0.08
# Layer 0 head 6: 0.29
# Layer 0 head 7: 0.06
# Layer 0 head 8: 0.21
# Layer 0 head 9: 0.11
# Layer 0 head 10: 0.13
# Layer 0 head 11: 0.22
# Layer 1 head 0: 0.28
# Layer 1 head 1: 0.53
# Layer 1 head 2: 0.76
# Layer 1 head 3: 0.49
# Layer 1 head 4: 0.5
# Layer 1 head 5: 0.53
# Layer 1 head 6: 0.4
# Layer 1 head 7: 0.58
# Layer 1 head 8: 0.47
# Layer 1 head 9: 0.46
# Layer 1 head 10: 0.72
# Layer 1 head 11: 0.34
# Layer 2 head 0: 0.35
# Layer 2 head 1: 0.39
# Layer 2 head 2: 0.15
# Layer 2 head 3: 0.22
# Layer 2 head 4: 0.15
# Layer 2 head 5: 0.12
# Layer 2 head 6: 0.15
# Layer 2 head 7: 0.07
# Layer 2 head 8: 0.17
# Layer 2 head 9: 0.15
# Layer 2 head 10: 0.06
# Layer 2 head 11: 0.12
# Layer 3 head 0: 0.03
# Layer 3 head 1: 0.06
# Layer 3 head 2: 0.01
# Layer 3 head 3: 0.05
# Layer 3 head 4: 0.03
# Layer 3 head 5: 0.07
# Layer 3 head 6: 0.02
# Layer 3 head 7: 0.04
# Layer 3 head 8: 0.09
# Layer 3 head 9: 0.02
# Layer 3 head 10: 0.03
# Layer 3 head 11: 0.23
# Layer 4 head 0: 0.02
# Layer 4 head 1: 0.0
# Layer 4 head 2: 0.02
# Layer 4 head 3: 0.01
# Layer 4 head 4: 0.05
# Layer 4 head 5: 0.03
# Layer 4 head 6: 0.03
# Layer 4 head 7: 0.06
# Layer 4 head 8: 0.04
# Layer 4 head 9: 0.01
# Layer 4 head 10: 0.02
# Layer 4 head 11: 0.06
# Layer 5 head 0: 0.04
# Layer 5 head 1: 0.03
# Layer 5 head 2: 0.01
# Layer 5 head 3: 0.02
# Layer 5 head 4: 0.01
# Layer 5 head 5: 0.01
# Layer 5 head 6: 0.02
# Layer 5 head 7: 0.02
# Layer 5 head 8: 0.04
# Layer 5 head 9: 0.01
# Layer 5 head 10: 0.02
# Layer 5 head 11: 0.01
# Layer 6 head 0: 0.09
# Layer 6 head 1: 0.02
# Layer 6 head 2: 0.01
# Layer 6 head 3: 0.0
# Layer 6 head 4: 0.02
# Layer 6 head 5: 0.01
# Layer 6 head 6: 0.01
# Layer 6 head 7: 0.02
# Layer 6 head 8: 0.01
# Layer 6 head 9: 0.03
# Layer 6 head 10: 0.01
# Layer 6 head 11: 0.03
# Layer 7 head 0: 0.01
# Layer 7 head 1: 0.01
# Layer 7 head 2: 0.01
# Layer 7 head 3: 0.05
# Layer 7 head 4: 0.01
# Layer 7 head 5: 0.0
# Layer 7 head 6: 0.0
# Layer 7 head 7: 0.02
# Layer 7 head 8: 0.0
# Layer 7 head 9: 0.0
# Layer 7 head 10: 0.0
# Layer 7 head 11: 0.0
# Layer 8 head 0: 0.01
# Layer 8 head 1: 0.01
# Layer 8 head 2: 0.09
# Layer 8 head 3: 0.0
# Layer 8 head 4: 0.01
# Layer 8 head 5: 0.03
# Layer 8 head 6: 0.0
# Layer 8 head 7: 0.03
# Layer 8 head 8: 0.0
# Layer 8 head 9: 0.01
# Layer 8 head 10: 0.04
# Layer 8 head 11: 0.01
# Layer 9 head 0: 0.01
# Layer 9 head 1: 0.0
# Layer 9 head 2: 0.03
# Layer 9 head 3: 0.01
# Layer 9 head 4: 0.0
# Layer 9 head 5: 0.02
# Layer 9 head 6: 0.01
# Layer 9 head 7: 0.01
# Layer 9 head 8: 0.0
# Layer 9 head 9: 0.0
# Layer 9 head 10: 0.01
# Layer 9 head 11: 0.0
# Layer 10 head 0: 0.03
# Layer 10 head 1: 0.03
# Layer 10 head 2: 0.02
# Layer 10 head 3: 0.0
# Layer 10 head 4: 0.0
# Layer 10 head 5: 0.03
# Layer 10 head 6: 0.02
# Layer 10 head 7: 0.01
# Layer 10 head 8: 0.02
# Layer 10 head 9: 0.02
# Layer 10 head 10: 0.07
# Layer 10 head 11: 0.06
# Layer 11 head 0: 0.02
# Layer 11 head 1: 0.02
# Layer 11 head 2: 0.01
# Layer 11 head 3: 0.01
# Layer 11 head 4: 0.01
# Layer 11 head 5: 0.02
# Layer 11 head 6: 0.01
# Layer 11 head 7: 0.01
# Layer 11 head 8: 0.05
# Layer 11 head 9: 0.02
# Layer 11 head 10: 0.01
# Layer 11 head 11: 0.01
# Attention to [SEP] token
# Layer 0 head 0: 0.12
# Layer 0 head 1: 0.12
# Layer 0 head 2: 0.13
# Layer 0 head 3: 0.13
# Layer 0 head 4: 0.12
# Layer 0 head 5: 0.12
# Layer 0 head 6: 0.13
# Layer 0 head 7: 0.13
# Layer 0 head 8: 0.13
# Layer 0 head 9: 0.12
# Layer 0 head 10: 0.12
# Layer 0 head 11: 0.13
# Layer 1 head 0: 0.13
# Layer 1 head 1: 0.13
# Layer 1 head 2: 0.12
# Layer 1 head 3: 0.12
# Layer 1 head 4: 0.13
# Layer 1 head 5: 0.12
# Layer 1 head 6: 0.12
# Layer 1 head 7: 0.12
# Layer 1 head 8: 0.12
# Layer 1 head 9: 0.13
# Layer 1 head 10: 0.12
# Layer 1 head 11: 0.12
# Layer 2 head 0: 0.13
# Layer 2 head 1: 0.13
# Layer 2 head 2: 0.12
# Layer 2 head 3: 0.12
# Layer 2 head 4: 0.12
# Layer 2 head 5: 0.13
# Layer 2 head 6: 0.12
# Layer 2 head 7: 0.12
# Layer 2 head 8: 0.12
# Layer 2 head 9: 0.12
# Layer 2 head 10: 0.13
# Layer 2 head 11: 0.12
# Layer 3 head 0: 0.12
# Layer 3 head 1: 0.12
# Layer 3 head 2: 0.12
# Layer 3 head 3: 0.13
# Layer 3 head 4: 0.12
# Layer 3 head 5: 0.12
# Layer 3 head 6: 0.13
# Layer 3 head 7: 0.12
# Layer 3 head 8: 0.13
# Layer 3 head 9: 0.12
# Layer 3 head 10: 0.13
# Layer 3 head 11: 0.12
# Layer 4 head 0: 0.12
# Layer 4 head 1: 0.12
# Layer 4 head 2: 0.13
# Layer 4 head 3: 0.13
# Layer 4 head 4: 0.13
# Layer 4 head 5: 0.13
# Layer 4 head 6: 0.12
# Layer 4 head 7: 0.12
# Layer 4 head 8: 0.13
# Layer 4 head 9: 0.13
# Layer 4 head 10: 0.12
# Layer 4 head 11: 0.12
# Layer 5 head 0: 0.13
# Layer 5 head 1: 0.12
# Layer 5 head 2: 0.12
# Layer 5 head 3: 0.13
# Layer 5 head 4: 0.12
# Layer 5 head 5: 0.13
# Layer 5 head 6: 0.13
# Layer 5 head 7: 0.13
# Layer 5 head 8: 0.13
# Layer 5 head 9: 0.12
# Layer 5 head 10: 0.13
# Layer 5 head 11: 0.13
# Layer 6 head 0: 0.13
# Layer 6 head 1: 0.13
# Layer 6 head 2: 0.13
# Layer 6 head 3: 0.13
# Layer 6 head 4: 0.12
# Layer 6 head 5: 0.12
# Layer 6 head 6: 0.13
# Layer 6 head 7: 0.13
# Layer 6 head 8: 0.12
# Layer 6 head 9: 0.12
# Layer 6 head 10: 0.12
# Layer 6 head 11: 0.12
# Layer 7 head 0: 0.12
# Layer 7 head 1: 0.13
# Layer 7 head 2: 0.13
# Layer 7 head 3: 0.12
# Layer 7 head 4: 0.13
# Layer 7 head 5: 0.12
# Layer 7 head 6: 0.12
# Layer 7 head 7: 0.13
# Layer 7 head 8: 0.12
# Layer 7 head 9: 0.13
# Layer 7 head 10: 0.12
# Layer 7 head 11: 0.13
# Layer 8 head 0: 0.13
# Layer 8 head 1: 0.12
# Layer 8 head 2: 0.13
# Layer 8 head 3: 0.13
# Layer 8 head 4: 0.12
# Layer 8 head 5: 0.13
# Layer 8 head 6: 0.12
# Layer 8 head 7: 0.12
# Layer 8 head 8: 0.12
# Layer 8 head 9: 0.13
# Layer 8 head 10: 0.12
# Layer 8 head 11: 0.12
# Layer 9 head 0: 0.12
# Layer 9 head 1: 0.12
# Layer 9 head 2: 0.13
# Layer 9 head 3: 0.12
# Layer 9 head 4: 0.12
# Layer 9 head 5: 0.13
# Layer 9 head 6: 0.13
# Layer 9 head 7: 0.13
# Layer 9 head 8: 0.13
# Layer 9 head 9: 0.13
# Layer 9 head 10: 0.12
# Layer 9 head 11: 0.12
# Layer 10 head 0: 0.12
# Layer 10 head 1: 0.12
# Layer 10 head 2: 0.13
# Layer 10 head 3: 0.12
# Layer 10 head 4: 0.13
# Layer 10 head 5: 0.13
# Layer 10 head 6: 0.13
# Layer 10 head 7: 0.13
# Layer 10 head 8: 0.12
# Layer 10 head 9: 0.12
# Layer 10 head 10: 0.13
# Layer 10 head 11: 0.12
# Layer 11 head 0: 0.12
# Layer 11 head 1: 0.12
# Layer 11 head 2: 0.13
# Layer 11 head 3: 0.12
# Layer 11 head 4: 0.13
# Layer 11 head 5: 0.13
# Layer 11 head 6: 0.13
# Layer 11 head 7: 0.12
# Layer 11 head 8: 0.13
# Layer 11 head 9: 0.12
# Layer 11 head 10: 0.12
# Layer 11 head 11: 0.13
# Attention from [SEP] token
# Layer 0 head 0: 0.26
# Layer 0 head 1: 0.08
# Layer 0 head 2: 0.2
# Layer 0 head 3: 0.16
# Layer 0 head 4: 0.26
# Layer 0 head 5: 0.18
# Layer 0 head 6: 0.24
# Layer 0 head 7: 0.24
# Layer 0 head 8: 0.19
# Layer 0 head 9: 0.15
# Layer 0 head 10: 0.13
# Layer 0 head 11: 0.07
# Layer 1 head 0: 0.23
# Layer 1 head 1: 0.05
# Layer 1 head 2: 0.03
# Layer 1 head 3: 0.06
# Layer 1 head 4: 0.05
# Layer 1 head 5: 0.08
# Layer 1 head 6: 0.27
# Layer 1 head 7: 0.05
# Layer 1 head 8: 0.21
# Layer 1 head 9: 0.17
# Layer 1 head 10: 0.04
# Layer 1 head 11: 0.11
# Layer 2 head 0: 0.18
# Layer 2 head 1: 0.26
# Layer 2 head 2: 0.19
# Layer 2 head 3: 0.05
# Layer 2 head 4: 0.43
# Layer 2 head 5: 0.67
# Layer 2 head 6: 0.4
# Layer 2 head 7: 0.54
# Layer 2 head 8: 0.44
# Layer 2 head 9: 0.53
# Layer 2 head 10: 0.41
# Layer 2 head 11: 0.37
# Layer 3 head 0: 0.7
# Layer 3 head 1: 0.51
# Layer 3 head 2: 0.55
# Layer 3 head 3: 0.53
# Layer 3 head 4: 0.52
# Layer 3 head 5: 0.57
# Layer 3 head 6: 0.71
# Layer 3 head 7: 0.64
# Layer 3 head 8: 0.16
# Layer 3 head 9: 0.57
# Layer 3 head 10: 0.57
# Layer 3 head 11: 0.05
# Layer 4 head 0: 0.86
# Layer 4 head 1: 0.85
# Layer 4 head 2: 0.55
# Layer 4 head 3: 0.51
# Layer 4 head 4: 0.5
# Layer 4 head 5: 0.69
# Layer 4 head 6: 0.6
# Layer 4 head 7: 0.69
# Layer 4 head 8: 0.59
# Layer 4 head 9: 0.58
# Layer 4 head 10: 0.56
# Layer 4 head 11: 0.65
# Layer 5 head 0: 0.46
# Layer 5 head 1: 0.43
# Layer 5 head 2: 0.61
# Layer 5 head 3: 0.64
# Layer 5 head 4: 0.66
# Layer 5 head 5: 0.73
# Layer 5 head 6: 0.56
# Layer 5 head 7: 0.59
# Layer 5 head 8: 0.57
# Layer 5 head 9: 0.78
# Layer 5 head 10: 0.84
# Layer 5 head 11: 0.65
# Layer 6 head 0: 0.62
# Layer 6 head 1: 0.63
# Layer 6 head 2: 0.91
# Layer 6 head 3: 0.65
# Layer 6 head 4: 0.5
# Layer 6 head 5: 0.5
# Layer 6 head 6: 0.63
# Layer 6 head 7: 0.61
# Layer 6 head 8: 0.75
# Layer 6 head 9: 0.42
# Layer 6 head 10: 0.89
# Layer 6 head 11: 0.56
# Layer 7 head 0: 0.69
# Layer 7 head 1: 0.7
# Layer 7 head 2: 0.83
# Layer 7 head 3: 0.48
# Layer 7 head 4: 0.62
# Layer 7 head 5: 0.47
# Layer 7 head 6: 0.56
# Layer 7 head 7: 0.57
# Layer 7 head 8: 0.76
# Layer 7 head 9: 0.96
# Layer 7 head 10: 0.68
# Layer 7 head 11: 0.78
# Layer 8 head 0: 0.68
# Layer 8 head 1: 0.55
# Layer 8 head 2: 0.61
# Layer 8 head 3: 0.7
# Layer 8 head 4: 0.79
# Layer 8 head 5: 0.73
# Layer 8 head 6: 0.69
# Layer 8 head 7: 0.46
# Layer 8 head 8: 0.74
# Layer 8 head 9: 0.75
# Layer 8 head 10: 0.61
# Layer 8 head 11: 0.71
# Layer 9 head 0: 0.72
# Layer 9 head 1: 0.79
# Layer 9 head 2: 0.75
# Layer 9 head 3: 0.41
# Layer 9 head 4: 0.79
# Layer 9 head 5: 0.55
# Layer 9 head 6: 0.5
# Layer 9 head 7: 0.69
# Layer 9 head 8: 0.58
# Layer 9 head 9: 0.41
# Layer 9 head 10: 0.43
# Layer 9 head 11: 0.78
# Layer 10 head 0: 0.69
# Layer 10 head 1: 0.63
# Layer 10 head 2: 0.73
# Layer 10 head 3: 0.91
# Layer 10 head 4: 0.79
# Layer 10 head 5: 0.61
# Layer 10 head 6: 0.6
# Layer 10 head 7: 0.73
# Layer 10 head 8: 0.74
# Layer 10 head 9: 0.72
# Layer 10 head 10: 0.77
# Layer 10 head 11: 0.73
# Layer 11 head 0: 0.81
# Layer 11 head 1: 0.8
# Layer 11 head 2: 0.3
# Layer 11 head 3: 0.12
# Layer 11 head 4: 0.78
# Layer 11 head 5: 0.72
# Layer 11 head 6: 0.65
# Layer 11 head 7: 0.83
# Layer 11 head 8: 0.56
# Layer 11 head 9: 0.69
# Layer 11 head 10: 0.73
# Layer 11 head 11: 0.19
